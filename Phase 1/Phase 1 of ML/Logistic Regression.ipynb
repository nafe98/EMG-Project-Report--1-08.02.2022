# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %% [markdown]
# # Exploratory Data Analysis

# %%
raw_data = pd.read_excel('Dataset1 .xlsx')
raw_data.sample(50)
# Out:
#           emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8  \
# 14023   0.0586  0.5640  0.2051  0.0024  0.0024  0.0024  0.0146  0.1318
# 68790   0.0122  0.0024  0.0024  0.0024  0.0024  0.0024  0.1221  0.1978
# 23626   0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0049  0.0586
# 75896   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0464
# 94558   0.0049  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0513
# 24163   0.0171  0.0024  0.0049  0.0024  0.0024  0.0024  0.0024  0.0757
# 88780   0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0146  0.0464
# 88200   0.0073  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415  0.0610
# 42047   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.4224  0.1221
# 78979   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0269
# 27374   0.1563  0.7202  0.2734  0.0317  0.0171  0.0464  0.9668  0.4028
# 38916   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.3296  0.1294
# ...

# %%
raw_data.shape
# Out:
# (101014, 14)

# %%
raw_data.columns
# Out:
# Index(['emg1', 'emg2', 'emg3', 'emg4', 'emg5', 'emg6', 'emg7', 'emg8', 'emg9',
#        'emg10', 'repetition', 'rerepetition', 'stimulus', 'restimulus'],
#       dtype='object')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101014 entries, 0 to 101013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   emg1          101014 non-null  float64
#  1   emg2          101014 non-null  float64
#  2   emg3          101014 non-null  float64
#  3   emg4          101014 non-null  float64
#  4   emg5          101014 non-null  float64
#  5   emg6          101014 non-null  float64
#  6   emg7          101014 non-null  float64
#  7   emg8          101014 non-null  float64
#  8   emg9          101014 non-null  float64
#  9   emg10         101014 non-null  float64
#  10  repetition    101014 non-null  int64
#  11  rerepetition  101014 non-null  int64
#  12  stimulus      101014 non-null  int64
#  13  restimulus    101014 non-null  int64
# dtypes: float64(10), int64(4)
# memory usage: 10.8 MB

# %%
raw_data.describe(include='all')
# Out:
#                 emg1           emg2           emg3           emg4  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.039693       0.086158       0.041308       0.012502
# std         0.127180       0.231539       0.101912       0.031334
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.002400       0.002400       0.002400       0.002400
# 75%         0.024400       0.002400       0.012200       0.002400
# max         2.399900       2.480500       1.340300       0.446800
#
#                 emg5           emg6           emg7           emg8  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.003868       0.005367       0.167648       0.116476
# std         0.009796       0.021238       0.403823       0.174862
# min         0.002400       0.000000       0.002400       0.002400
# ...

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     39063
# 2      5174
# 4      5173
# 5      5173
# 12     5173
# 8      5172
# 7      5171
# 6      5170
# 11     5166
# 3      5158
# 1      5149
# 10     5137
# 9      5135
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Data Cleaning and Exploratory Data Analysis with New Data

# %%
index_names = raw_data[ (raw_data['stimulus'] != raw_data['restimulus'])].index
raw_data.drop(index_names, inplace = True)
print(raw_data)
# Out:
#           emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 101009  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0366
# 101010  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101011  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101012  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 101013  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391
#
#           emg9   emg10  repetition  rerepetition  stimulus  restimulus
# ...

# %%
index_names = raw_data[ (raw_data['repetition'] != raw_data['rerepetition'])].index
raw_data.drop(index_names, inplace = True)
print(raw_data)
# Out:
#           emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 101009  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0366
# 101010  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101011  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101012  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 101013  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391
#
#           emg9   emg10  repetition  rerepetition  stimulus  restimulus
# ...

# %%
raw_data.sample(20)
# Out:
#          emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8    emg9  \
# 3157   0.1270  0.8276  0.4736  0.1001  0.0415  0.0122  0.6372  0.1563  0.7837
# 4952   0.0024  0.0098  0.0513  0.0024  0.0024  0.0024  0.1147  0.0391  0.2222
# 74747  0.0195  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.0757  0.0024
# 72670  0.3369  1.3135  0.1978  0.0488  0.0073  0.0171  0.4004  1.4624  0.4028
# 15490  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0293  0.0024
# 85146  0.0049  0.0757  0.0024  0.0024  0.0024  0.0024  0.1270  0.0903  0.0146
# 77297  0.0073  0.0024  0.0024  0.0024  0.0024  0.0024  0.0195  0.0757  0.0024
# 81101  0.0220  0.0146  0.1123  0.0073  0.0024  0.0024  0.0732  0.0830  0.0024
# 81994  0.0342  0.0806  0.2002  0.0464  0.0024  0.0024  0.0854  0.0928  0.0024
# 84990  0.0122  0.0024  0.0024  0.0024  0.0024  0.0024  0.0781  0.0928  0.0024
# 60656  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0293  0.0024
# ...

# %%
raw_data.shape
# Out:
# (75043, 14)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75043 entries, 0 to 101013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   emg1          75043 non-null  float64
#  1   emg2          75043 non-null  float64
#  2   emg3          75043 non-null  float64
#  3   emg4          75043 non-null  float64
#  4   emg5          75043 non-null  float64
#  5   emg6          75043 non-null  float64
#  6   emg7          75043 non-null  float64
#  7   emg8          75043 non-null  float64
#  8   emg9          75043 non-null  float64
#  9   emg10         75043 non-null  float64
#  10  repetition    75043 non-null  int64
#  11  rerepetition  75043 non-null  int64
#  12  stimulus      75043 non-null  int64
#  13  restimulus    75043 non-null  int64
# dtypes: float64(10), int64(4)
# memory usage: 10.6 MB

# %%
print(raw_data.isnull().any())
# Out:
# emg1            False
# emg2            False
# emg3            False
# emg4            False
# emg5            False
# emg6            False
# emg7            False
# emg8            False
# emg9            False
# emg10           False
# repetition      False
# rerepetition    False
# stimulus        False
# restimulus      False
# dtype: bool

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %%
# Splitting data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 39)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LogisticRegression11 = LogisticRegression()
LogisticRegression11.fit(X_train, y_train)
# Out:
# C:\Users\nafem\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred51 = LogisticRegression11.predict(X_test)
from sklearn.metrics import accuracy_score
log_accuracy11 = {accuracy_score(y_test, y_pred51)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred51)* 100}")
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred51))

cm = confusion_matrix(y_pred51, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Accuracy is: 79.0658937970551
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88      7647
#            1       0.76      0.60      0.67       760
#            2       0.88      0.76      0.81       497
#            3       0.64      0.55      0.59       750
#            4       0.93      0.74      0.82       631
#            5       0.77      0.73      0.75       772
#            6       0.82      0.54      0.66       628
#            7       0.92      0.76      0.83       517
#            8       0.75      0.56      0.64       595
#            9       0.74      0.59      0.66       487
#           10       0.85      0.37      0.51       596
#           11       0.65      0.58      0.61       476
#           12       0.70      0.34      0.46       653
#
#     accuracy                           0.79     15009
#    macro avg       0.78      0.62      0.68     15009
# ...
