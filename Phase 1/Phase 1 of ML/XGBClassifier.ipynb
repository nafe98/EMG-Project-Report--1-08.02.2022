# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %% [markdown]
# # Exploratory Data Analysis

# %%
raw_data = pd.read_excel('Dataset1 .xlsx')
raw_data.sample(50)
# Out:
#          emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8    emg9  \
# 66552  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0806  0.0171  0.0024
# 29285  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.0342  0.0024
# 45743  0.0024  0.0024  0.0171  0.0146  0.0024  0.0024  0.0220  0.0830  0.0024
# 50509  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0122  0.0586  0.0024
# 15798  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0293  0.0024
# 9729   0.0024  0.1929  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.0269
# 25053  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0879  0.0024
# 31151  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488  0.0171  0.0024
# 66749  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0195  0.0024
# 33652  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0391  0.0049
# 39819  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.2466  0.0659  0.0024
# 8302   0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.1001  0.0342  0.0879
# 35746  0.1831  0.1782  0.5859  0.2173  0.0342  0.0415  1.3892  0.7861  1.0913
# 47166  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0244  0.0024
# 89513  0.0293  0.1294  0.0024  0.0049  0.0024  0.0024  0.0635  0.2808  0.0488
# 11414  0.0146  0.2515  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.0977
# 57756  0.0806  0.0024  0.0024  0.0024  0.0024  0.0024  0.7153  0.1538  0.0024
# 84673  0.0049  0.0024  0.0024  0.0024  0.0024  0.0024  0.1294  0.0757  0.0024
# 51103  0.0146  0.0024  0.0049  0.0024  0.0024  0.0024  0.1465  0.0757  0.0024
# 48502  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0195  0.0562  0.0024
# 95589  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.1001  0.0439  0.0024
# 81514  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0708  0.0659  0.0024
# 72745  0.2197  1.3574  0.1367  0.0146  0.0024  0.0024  0.2734  1.1743  0.3809
# 46272  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0342  0.0024
# 90295  0.1538  1.0547  0.1563  0.0122  0.0024  0.0024  0.1001  1.0693  0.3906
# 24986  0.0244  0.0024  0.0171  0.0024  0.0024  0.0024  0.0098  0.1147  0.1099
# 36246  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.1147  0.1074  0.0024
# 60551  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0171  0.0024
# 87680  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513  0.0464  0.0024
# 8282   0.0024  0.1538  0.1196  0.0024  0.0024  0.0024  0.0439  0.0342  0.1758
# 26193  0.0049  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0732  0.0024
# 7151   0.0122  0.0537  0.0415  0.0024  0.0024  0.0024  0.0293  0.0464  0.0903
# 56604  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.1099  0.0464  0.0024
# 93320  0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0317  0.0464  0.0024
# 57616  0.7837  0.4712  0.3125  0.1807  0.0171  0.0537  1.1963  0.2686  0.2637
# 91156  0.0952  0.5542  0.0464  0.0024  0.0024  0.0024  0.0488  0.5371  0.1978
# 2746   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.0269  0.0024
# 75064  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0171  0.0439  0.0024
# 63515  0.0928  0.0024  0.0732  0.0171  0.0024  0.0049  0.2930  0.2979  0.2979
# 91463  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0464  0.0024
# 68456  0.0073  0.0269  0.0024  0.0024  0.0024  0.0024  0.0830  0.1807  0.0537
# 15831  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0244  0.0024
# 99082  0.0073  0.0024  0.0024  0.0024  0.0024  0.0024  0.0122  0.0732  0.0024
# 74168  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513  0.0586  0.0024
# 89135  0.0146  0.0024  0.0049  0.0024  0.0024  0.0024  0.0635  0.0952  0.0024
# 59417  0.0684  0.0024  0.0024  0.0024  0.0024  0.0073  0.1953  0.1733  0.0610
# 87977  0.0073  0.0024  0.0049  0.0024  0.0024  0.0024  0.0952  0.0732  0.0024
# 14972  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0293  0.0024
# 84328  0.0122  0.0024  0.0024  0.0024  0.0024  0.0024  0.1221  0.0854  0.0024
# 72986  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0586  0.0635  0.0024
#
#         emg10  repetition  rerepetition  stimulus  restimulus
# 66552  0.0195           0             0         0           0
# 29285  0.0049           5             0         4           0
# 45743  0.0562           5             5         6           6
# 50509  0.0024           0             0         0           0
# 15798  0.0024           9             0         2           0
# 9729   0.2710           2             2         2           2
# 25053  0.0024          10            10         3           3
# 31151  0.0195           0             0         0           0
# 66749  0.0366          10             0         8           0
# 33652  0.0244           0             0         0           0
# 39819  0.0195           8             0         5           0
# 8302   0.0757          10            10         1           1
# 35746  0.1074           3             3         5           5
# 47166  0.0024           0             0         0           0
# 89513  0.0146           7             7        11          11
# 11414  0.1025           4             4         2           2
# 57756  0.1587           9             9         7           7
# 84673  0.0171           1             0        11           0
# 51103  0.1050           1             0         7           0
# 48502  0.0757           8             0         6           0
# 95589  0.0122           4             0        12           0
# 81514  0.0024           0             0         0           0
# 72745  0.4785           7             7         9           9
# 46272  0.0024           0             0         0           0
# 90295  0.3418           8             8        11          11
# 24986  0.0146          10            10         3           3
# 36246  0.0146           0             0         0           0
# 60551  0.0024           0             0         0           0
# 87680  0.0024           5             0        11           0
# 8282   0.1172          10            10         1           1
# 26193  0.0098           0             0         0           0
# 7151   0.0171           9             9         1           1
# 56604  0.0635           8             0         7           0
# 93320  0.0122           0             0         0           0
# 57616  0.3906           9             9         7           7
# 91156  0.1343           9             9        11          11
# 2746   0.0073           0             0         0           0
# 75064  0.0024          10             0         9           0
# 63515  0.0757           6             6         8           8
# 91463  0.0024           0             0         0           0
# 68456  0.0220           2             2         9           9
# 15831  0.0024           9             0         2           0
# 99082  0.0220           0             0         0           0
# 74168  0.0244           0             0         0           0
# 89135  0.0024           0             0         0           0
# 59417  0.1001           1             1         8           8
# 87977  0.0122           5             0        11           0
# 14972  0.0024           8             0         2           0
# 84328  0.0049           1             0        11           0
# 72986  0.0146           7             0         9           0

# %%
raw_data.shape
# Out:
# (101014, 14)

# %%
raw_data.columns
# Out:
# Index(['emg1', 'emg2', 'emg3', 'emg4', 'emg5', 'emg6', 'emg7', 'emg8', 'emg9',
#        'emg10', 'repetition', 'rerepetition', 'stimulus', 'restimulus'],
#       dtype='object')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101014 entries, 0 to 101013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   emg1          101014 non-null  float64
#  1   emg2          101014 non-null  float64
#  2   emg3          101014 non-null  float64
#  3   emg4          101014 non-null  float64
#  4   emg5          101014 non-null  float64
#  5   emg6          101014 non-null  float64
#  6   emg7          101014 non-null  float64
#  7   emg8          101014 non-null  float64
#  8   emg9          101014 non-null  float64
#  9   emg10         101014 non-null  float64
#  10  repetition    101014 non-null  int64
#  11  rerepetition  101014 non-null  int64
#  12  stimulus      101014 non-null  int64
#  13  restimulus    101014 non-null  int64
# dtypes: float64(10), int64(4)
# memory usage: 10.8 MB

# %%
raw_data.describe(include='all')
# Out:
#                 emg1           emg2           emg3           emg4  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.039693       0.086158       0.041308       0.012502
# std         0.127180       0.231539       0.101912       0.031334
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.002400       0.002400       0.002400       0.002400
# 75%         0.024400       0.002400       0.012200       0.002400
# max         2.399900       2.480500       1.340300       0.446800
#
#                 emg5           emg6           emg7           emg8  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.003868       0.005367       0.167648       0.116476
# std         0.009796       0.021238       0.403823       0.174862
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.009800       0.039100
# 50%         0.002400       0.002400       0.046400       0.061000
# 75%         0.002400       0.002400       0.129400       0.109900
# max         0.293000       0.639600       4.660600       3.000500
#
#                 emg9          emg10     repetition   rerepetition  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.073460       0.054120       3.372948       2.055349
# std         0.156381       0.112567       3.497555       3.188164
# min         0.000000       0.002400       0.000000       0.000000
# 25%         0.002400       0.004900       0.000000       0.000000
# 50%         0.002400       0.017100       2.000000       0.000000
# 75%         0.068400       0.048800       6.000000       4.000000
# max         1.752900       1.599100      10.000000      10.000000
#
#             stimulus     restimulus
# count  101014.000000  101014.000000
# mean        3.985665       2.329905
# std         4.162080       3.691976
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         3.000000       0.000000
# 75%         8.000000       4.000000
# max        12.000000      12.000000

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     39063
# 2      5174
# 4      5173
# 5      5173
# 12     5173
# 8      5172
# 7      5171
# 6      5170
# 11     5166
# 3      5158
# 1      5149
# 10     5137
# 9      5135
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Data Cleaning and Exploratory Data Analysis with New Data

# %%
index_names = raw_data[ (raw_data['stimulus'] != raw_data['restimulus'])].index
raw_data.drop(index_names, inplace = True)
print(raw_data)
# Out:
#           emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 101009  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0366
# 101010  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101011  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101012  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 101013  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391
#
#           emg9   emg10  repetition  rerepetition  stimulus  restimulus
# 0       0.0024  0.0342           0             0         0           0
# 1       0.0024  0.0293           0             0         0           0
# 2       0.0024  0.0244           0             0         0           0
# 3       0.0024  0.0171           0             0         0           0
# 4       0.0024  0.0146           0             0         0           0
# ...        ...     ...         ...           ...       ...         ...
# 101009  0.0024  0.0024           0             0         0           0
# 101010  0.0024  0.0024           0             0         0           0
# 101011  0.0024  0.0073           0             0         0           0
# 101012  0.0024  0.0073           0             0         0           0
# 101013  0.0024  0.0024           0             0         0           0
#
# [75043 rows x 14 columns]

# %%
index_names = raw_data[ (raw_data['repetition'] != raw_data['rerepetition'])].index
raw_data.drop(index_names, inplace = True)
print(raw_data)
# Out:
#           emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 101009  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0366
# 101010  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101011  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101012  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 101013  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391
#
#           emg9   emg10  repetition  rerepetition  stimulus  restimulus
# 0       0.0024  0.0342           0             0         0           0
# 1       0.0024  0.0293           0             0         0           0
# 2       0.0024  0.0244           0             0         0           0
# 3       0.0024  0.0171           0             0         0           0
# 4       0.0024  0.0146           0             0         0           0
# ...        ...     ...         ...           ...       ...         ...
# 101009  0.0024  0.0024           0             0         0           0
# 101010  0.0024  0.0024           0             0         0           0
# 101011  0.0024  0.0073           0             0         0           0
# 101012  0.0024  0.0073           0             0         0           0
# 101013  0.0024  0.0024           0             0         0           0
#
# [75043 rows x 14 columns]

# %%
raw_data.sample(20)
# Out:
#          emg1    emg2    emg3    emg4    emg5    emg6    emg7    emg8    emg9  \
# 97130  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513  0.0659  0.0024
# 49200  0.0366  0.6226  0.1123  0.0464  0.0024  0.0024  0.4590  0.1782  0.2930
# 52553  0.6860  0.1904  0.1709  0.0366  0.0049  0.0024  0.0977  0.1123  0.0708
# 99695  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0098  0.0586  0.0049
# 76633  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0269  0.0684  0.0024
# 48296  0.1294  0.2856  0.2759  0.0806  0.0098  0.0098  0.4395  0.2417  0.2173
# 80987  0.0171  0.0024  0.0586  0.0024  0.0024  0.0024  0.1587  0.0977  0.0024
# 43028  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0659  0.0024
# 44364  0.0269  0.0024  0.2759  0.2930  0.0073  0.0024  0.0708  0.2222  0.0024
# 3655   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342  0.0342  0.0024
# 14512  0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0024  0.0146  0.0024
# 32889  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0293  0.0024
# 33303  0.1904  1.4648  0.5566  0.0537  0.0586  0.1733  3.3081  0.5884  0.9668
# 47539  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0171  0.0684  0.0366
# 42504  0.1001  0.5444  0.4810  0.2637  0.0122  0.0122  0.7788  0.4321  0.4590
# 95128  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0293  0.0488  0.0024
# 79788  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0732  0.0342  0.0024
# 84514  0.0391  0.0879  0.0757  0.0024  0.0024  0.0024  0.3149  0.2979  0.0708
# 78675  0.1050  0.1465  0.2686  0.0464  0.0024  0.0024  0.0757  0.0806  0.0024
# 97489  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0464  0.0488  0.0024
#
#         emg10  repetition  rerepetition  stimulus  restimulus
# 97130  0.0195           6             6        12          12
# 49200  0.4492           9             9         6           6
# 52553  0.1636           3             3         7           7
# 99695  0.0366           9             9        12          12
# 76633  0.0024           0             0         0           0
# 48296  0.4785           8             8         6           6
# 80987  0.0024           7             7        10          10
# 43028  0.0220           0             0         0           0
# 44364  0.0391           3             3         6           6
# 3655   0.0073           0             0         0           0
# 14512  0.0024           0             0         0           0
# 32889  0.0146           0             0         0           0
# 33303  0.1709          10            10         4           4
# 47539  0.0146           7             7         6           6
# 42504  0.2759           1             1         6           6
# 95128  0.0366           0             0         0           0
# 79788  0.0146           0             0         0           0
# 84514  0.1245           1             1        11          11
# 78675  0.0513           4             4        10          10
# 97489  0.0244           0             0         0           0

# %%
raw_data.shape
# Out:
# (75043, 14)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75043 entries, 0 to 101013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   emg1          75043 non-null  float64
#  1   emg2          75043 non-null  float64
#  2   emg3          75043 non-null  float64
#  3   emg4          75043 non-null  float64
#  4   emg5          75043 non-null  float64
#  5   emg6          75043 non-null  float64
#  6   emg7          75043 non-null  float64
#  7   emg8          75043 non-null  float64
#  8   emg9          75043 non-null  float64
#  9   emg10         75043 non-null  float64
#  10  repetition    75043 non-null  int64
#  11  rerepetition  75043 non-null  int64
#  12  stimulus      75043 non-null  int64
#  13  restimulus    75043 non-null  int64
# dtypes: float64(10), int64(4)
# memory usage: 10.6 MB

# %%
print(raw_data.isnull().any())
# Out:
# emg1            False
# emg2            False
# emg3            False
# emg4            False
# emg5            False
# emg6            False
# emg7            False
# emg8            False
# emg9            False
# emg10           False
# repetition      False
# rerepetition    False
# stimulus        False
# restimulus      False
# dtype: bool

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %%
# Splitting data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 39)

# %% [markdown]
# # Decision Tree

# %%
from xgboost import XGBClassifier
tree11 = XGBClassifier()
tree11.fit(X_train, y_train)
# Out:
# C:\Users\nafem\anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12:35:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=4,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
y_pred41 = tree11.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
dt_accuracy11 = {accuracy_score(y_test, y_pred41)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred41)* 100}")
# Out:
# Accuracy is: 90.64561263242055

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred41))

cm = confusion_matrix(y_pred41, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      7647
#            1       0.92      0.88      0.90       760
#            2       0.97      0.88      0.92       497
#            3       0.87      0.85      0.86       750
#            4       0.95      0.92      0.94       631
#            5       0.93      0.90      0.91       772
#            6       0.90      0.83      0.86       628
#            7       0.97      0.93      0.95       517
#            8       0.92      0.85      0.89       595
#            9       0.89      0.83      0.86       487
#           10       0.96      0.72      0.82       596
#           11       0.84      0.84      0.84       476
#           12       0.88      0.49      0.63       653
#
#     accuracy                           0.91     15009
#    macro avg       0.91      0.84      0.87     15009
# weighted avg       0.91      0.91      0.90     15009
#
# Confusion Matrix :

# %% [markdown]
# https://analyticsindiamag.com/7-types-classification-algorithms/
